# %%
import sys
import os

# Ensure correct project path
PROJECT_PATH = "/home/jovyan/git/SurveyStudio"
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)

# Optional: change working directory (important for imports like parser_service)
os.chdir(PROJECT_PATH)

from backend.main import app
import uvicorn
import nest_asyncio

nest_asyncio.apply()

config = uvicorn.Config(
    app,
    host="0.0.0.0",
    port=5004,
    log_level="info"
)

server = uvicorn.Server(config)

await server.serve()
